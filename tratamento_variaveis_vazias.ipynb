# %%
'who_men'

# %%
titanic_df = sns.load_dataset('titanic')

# %%
columns_to_drop = ['embarked', 'embark_town', 'alive']

titanic_df = titanic_df.drop(columns=columns_to_drop)

titanic_df = titanic_df.drop(columns=['deck'])

media_idade = titanic_df["age"].mean()

titanic_df["age"] = titanic_df["age"].fillna(media_idade)

# %%
# Gráfico de barras
msno.bar(titanic_df)

# Mapa de calor de nulos
msno.matrix(titanic_df)
# Out:
# <Axes: >
